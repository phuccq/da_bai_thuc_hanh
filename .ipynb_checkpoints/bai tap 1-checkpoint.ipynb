# %% [markdown]
# # Khai bao thư viện

# %%
import pandas as pd
import numpy as np
print('Nhap du lieu thanh cong')
# Out:
# Nhap du lieu thanh cong

# %% [markdown]
# # Nhap du lieu

# %%
data = pd.read_csv('OnlineRetail.csv', header=0, encoding = 'ISO-8859-1')
display(data)
data.info()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # 1. Tìm số hàng và số cột của dữ liệu
# ## Xuất ra theo dạng "Số hàng là xxx, số cột là yyy"

# %%
print('Số hàng là:', data.shape[0], ', Số cột là:', data.shape[1])
# Out:
# Số hàng là: 541909 , Số cột là: 8

# %% [markdown]
# # 2. Việt hóa tên các cột (có dấu)
# **'So hoa don', 'Ma hang hoa', 'Mo ta', 'So luong', 'Ngay', 'Don gia', 'Ma KH'**

# %%
data.columns = ['Số hóa đơn', 'Mã hàng hóa', 'Mô tả', 'Số lượng', 'Ngày', 'Đơn giá', 'Mã KH', 'Quốc gia']
data
# Out:
#        Số hóa đơn Mã hàng hóa                                Mô tả  Số lượng  \
# 0          536365      85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365       71053                  WHITE METAL LANTERN         6
# 2          536365      84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365      84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365      84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...         ...                                  ...       ...
# 541904     581587       22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905     581587       22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906     581587       23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907     581587       23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908     581587       22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %% [markdown]
# # 3. Thêm cột "Thành tiền" vào sau cuối, giá trị mặc định là 0

# %%
data['Thành tiền'] = 0
data
# Out:
#        Số hóa đơn Mã hàng hóa                                Mô tả  Số lượng  \
# 0          536365      85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365       71053                  WHITE METAL LANTERN         6
# 2          536365      84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365      84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365      84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...         ...                                  ...       ...
# 541904     581587       22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905     581587       22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906     581587       23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907     581587       23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908     581587       22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %% [markdown]
# object (chu) > float > int > NaN

# %% [markdown]
# # 4. Thêm cột "Chiết khấu" sau cột "Đơn giá"
# ## Giá trị của cột "Chiết khấu" = 3 (đơn vị %)

# %%
data.insert(6, 'Chiết khấu (%)', 3)
data
# Out:
#        Số hóa đơn Mã hàng hóa                                Mô tả  Số lượng  \
# 0          536365      85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365       71053                  WHITE METAL LANTERN         6
# 2          536365      84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365      84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365      84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...         ...                                  ...       ...
# 541904     581587       22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905     581587       22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906     581587       23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907     581587       23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908     581587       22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Số hóa đơn      541909 non-null  object
#  1   Mã hàng hóa     541909 non-null  object
#  2   Mô tả           540455 non-null  object
#  3   Số lượng        541909 non-null  int64
#  4   Ngày            541909 non-null  object
#  5   Đơn giá         541909 non-null  float64
#  6   Chiết khấu (%)  541909 non-null  int64
#  7   Mã KH           406829 non-null  float64
#  8   Quốc gia        541909 non-null  object
#  9   Thành tiền      541909 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 41.3+ MB

# %% [markdown]
# # 5. Thêm 1 sản phẩm sau hàng có index 541905
# ## Thông tin sp: 324345, 34534B, Noi chien khong dau, 1000, 23/6/2022 20:30, 50.2, 3, 312313.0, Vietnam, 0

# %%
data.loc[541905.5] = ['324345', '34534B', 'Noi chien khong dau', 1000, '23/6/2022 20:30', 50.2, 3, 312313.0, 'Vietnam', 0]
data = data.sort_index().reset_index(drop=True)
data
# Out:
#        Số hóa đơn Mã hàng hóa                                Mô tả  Số lượng  \
# 0          536365      85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365       71053                  WHITE METAL LANTERN         6
# 2          536365      84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365      84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365      84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...         ...                                  ...       ...
# 541905     581587       22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906     324345      34534B                  Noi chien khong dau      1000
# 541907     581587       23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541908     581587       23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541909     581587       22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   So hoa don      541909 non-null  object
#  1   Ma hang hoa     541909 non-null  object
#  2   Mo ta           540455 non-null  object
#  3   So luong        541909 non-null  int64
#  4   Ngay            541909 non-null  object
#  5   Don gia         541909 non-null  float64
#  6   Chiet khau (%)  541909 non-null  int64
#  7   Ma KH           406829 non-null  float64
#  8   Nuoc            541909 non-null  object
#  9   Tien            0 non-null       float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 41.3+ MB

# %%
#Them san pham vao hang cuoi cung
data.loc[data.shape[0]]=['324345', '34534B', 'Noi chien khong dau', 1000, '23/6/2022 20:30', 50.2, 3, 312313.0, 'Vietnam', np.NaN]
display(data)
# Out:
#        So hoa don Ma hang hoa                                Mo ta  So luong  \
# 0          536365      85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365       71053                  WHITE METAL LANTERN         6
# 2          536365      84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365      84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365      84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...         ...                                  ...       ...
# 541906     581587       23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907     581587       23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908     581587       22138        BAKING SET 9 PIECE RETROSPOT          3
# 541909     324345      34534B                  Noi chien khong dau      1000
# 541910     324345      34534B                  Noi chien khong dau      1000
#
# ...

# %%
#Them san pham vao sau hang 541905
data.loc[541905.5]=['324345', '34534B', 'Noi chien khong dau', 3000, '25/6/2022 20:30', 50.2, 3, 312313.0, 'Vietnam', np.NaN]
data = data.sort_index().reset_index(drop=True)
display(data)
# Out:
#        So hoa don Ma hang hoa                                Mo ta  So luong  \
# 0          536365      85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365       71053                  WHITE METAL LANTERN         6
# 2          536365      84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365      84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365      84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...         ...                                  ...       ...
# 541907     324345      34534B                  Noi chien khong dau      2000
# 541908     581587       23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541909     581587       22138        BAKING SET 9 PIECE RETROSPOT          3
# 541910     324345      34534B                  Noi chien khong dau      1000
# 541911     324345      34534B                  Noi chien khong dau      1000
#
# ...

# %%
data.tail(20)
# Out:
#        So hoa don Ma hang hoa                            Mo ta  So luong  \
# 541892     581586       21217    RED RETROSPOT ROUND CAKE TINS        24
# 541893     581586       20685            DOORMAT RED RETROSPOT        10
# 541894     581587       22631         CIRCUS PARADE LUNCH BOX         12
# 541895     581587       22556   PLASTERS IN TIN CIRCUS PARADE         12
# 541896     581587       22555        PLASTERS IN TIN STRONGMAN        12
# 541897     581587       22728        ALARM CLOCK BAKELIKE PINK         4
# 541898     581587       22727        ALARM CLOCK BAKELIKE RED          4
# 541899     581587       22726       ALARM CLOCK BAKELIKE GREEN         4
# 541900     581587       22730       ALARM CLOCK BAKELIKE IVORY         4
# 541901     581587       22367  CHILDRENS APRON SPACEBOY DESIGN         8
# 541902     581587       22629              SPACEBOY LUNCH BOX         12
# 541903     581587       23256      CHILDRENS CUTLERY SPACEBOY          4
# ...

# %% [markdown]
# # 6. Tinh tien roi nhap gia tri vao cot 'Tien' theo cong thuc sau:
# Tien = so luong x don gia x (100 - chiet khau (%))/100

# %%
data.loc[:,"Thành tiền"] = data.loc[:,"Số lượng"] * data.loc[:,"Đơn giá"] * (100 - data.loc[:,"Chiết khấu (%)"])/100
data
# Out:
#        Số hóa đơn Mã hàng hóa                                Mô tả  Số lượng  \
# 0          536365      85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365       71053                  WHITE METAL LANTERN         6
# 2          536365      84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365      84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365      84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...         ...                                  ...       ...
# 541905     581587       22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906     324345      34534B                  Noi chien khong dau      1000
# 541907     581587       23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541908     581587       23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541909     581587       22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
data['Tien'] = data['So luong']*data['Don gia']*(100-data['Chiet khau (%)'])/100
display(data)
# Out:
#        So hoa don Ma hang hoa                                Mo ta  So luong  \
# 0          536365      85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365       71053                  WHITE METAL LANTERN         6
# 2          536365      84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365      84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365      84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...         ...                                  ...       ...
# 541907     324345      34534B                  Noi chien khong dau      2000
# 541908     581587       23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541909     581587       22138        BAKING SET 9 PIECE RETROSPOT          3
# 541910     324345      34534B                  Noi chien khong dau      1000
# 541911     324345      34534B                  Noi chien khong dau      1000
#
# ...

# %% [markdown]
# # 7. Luu du lieu ra file
#
# df.to_excel('Tenfile.xlsx')

# %%
data.to_csv('Ketquahomnay.csv')
print('Xuat file thanh cong')
# Out:
# Xuat file thanh cong
